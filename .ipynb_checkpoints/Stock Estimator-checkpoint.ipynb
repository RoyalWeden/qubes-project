# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/all_stocks_5yr.csv')
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df = df.dropna()
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619029 rows x 7 columns]

# %%
df = df.rename(columns={'Name': 'symbol'})
df
# Out:
#               date   open   high    low  close    volume symbol
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500    AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000    AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000    AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500    AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900    AAL
# ...            ...    ...    ...    ...    ...       ...    ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259    ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187    ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031    ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323    ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912    ZTS
#
# [619029 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
date_enc = LabelEncoder()
date_enc.fit(df.loc[:, 'date'])
symbol_enc = LabelEncoder()
symbol_enc.fit(df.loc[:, 'symbol'])
# Out:
# LabelEncoder()

# %%
date_encoded = pd.DataFrame(date_enc.transform(df.loc[:, 'date']), columns=['date'])
date_encoded
# Out:
#         date
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 619024  1254
# 619025  1255
# 619026  1256
# 619027  1257
# 619028  1258
#
# [619029 rows x 1 columns]

# %%
symbol_encoded = pd.DataFrame(symbol_enc.transform(df.loc[:, 'symbol']), columns=['symbol'])
symbol_encoded
# Out:
#         symbol
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 619024     504
# 619025     504
# 619026     504
# 619027     504
# 619028     504
#
# [619029 rows x 1 columns]

# %%
scaled_volume = df['volume'].apply(lambda x: x/1000000) # convert volume to millions
scaled_volume
# Out:
# 0          8.407500
# 1          8.882000
# 2          8.126000
# 3         10.259500
# 4         31.879900
#             ...
# 619035     2.982259
# 619036     2.595187
# 619037     2.962031
# 619038     4.924323
# 619039     4.534912
# Name: volume, Length: 619029, dtype: float64

# %%
oc_change_by_volume = pd.DataFrame((df['close'] - df['open']) * scaled_volume, columns=['oc_change_by_volume'])
oc_change_by_volume
# Out:
#         oc_change_by_volume
# 0                 -2.690400
# 1                 -3.819260
# 2                 -1.462680
# 3                  3.693420
# 4                -30.285905
# ...                     ...
# 619035             2.922614
# 619036            -1.946390
# 619037            -8.323307
# 619038             2.609891
# 619039             5.260498
#
# [619029 rows x 1 columns]

# %%
df = symbol_encoded.merge(date_encoded, left_index=True, right_index=True)\
                   .merge(oc_change_by_volume, left_index=True, right_index=True)
df
# Out:
#         symbol  date  oc_change_by_volume
# 0            1     0            -2.690400
# 1            1     1            -3.819260
# 2            1     2            -1.462680
# 3            1     3             3.693420
# 4            1     4           -30.285905
# ...        ...   ...                  ...
# 619024     504  1254             2.658804
# 619025     504  1255            -0.828478
# 619026     504  1256            -0.338072
# 619027     504  1257             3.398033
# 619028     504  1258             0.656598
#
# [619018 rows x 3 columns]

# %%
mean_df = pd.DataFrame(columns=['symbol', 'mean_occbv'])
mean_df
# Out:
# Empty DataFrame
# Columns: [symbol, mean_occbv]
# Index: []

# %%
for i in range(max(df['symbol'])):
    selected_vals = df.loc[df['symbol']==i]['oc_change_by_volume']
    mean_df = mean_df.append({'symbol': i, 'mean_occbv': np.mean(selected_vals)}, ignore_index=True)
mean_df
# Out:
#      symbol  mean_occbv
# 0       0.0   -0.014811
# 1       1.0   -0.180699
# 2       2.0    0.006035
# 3       3.0   -2.028634
# 4       4.0    0.716824
# ..      ...         ...
# 499   499.0   -0.054346
# 500   500.0    0.012596
# 501   501.0    0.001243
# 502   502.0    0.018420
# 503   503.0    0.016044
#
# [504 rows x 2 columns]

# %%
from qiskit import Aer, QuantumCircuit
from qiskit.opflow import Z, I, StateFn
from qiskit.utils import QuantumInstance
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit.algorithms.optimizers import COBYLA, L_BFGS_B

from qiskit_machine_learning.neural_networks import TwoLayerQNN, CircuitQNN
from qiskit_machine_learning.algorithms.regressors import NeuralNetworkRegressor, VQR

from typing import Union

from qiskit_machine_learning.exceptions import QiskitMachineLearningError

# %%
quantum_instance = QuantumInstance(Aer.get_backend('aer_simulator'), shots=1024)

# %%
aal_df = df.loc[df['symbol']==i].drop(columns=['symbol']).set_index('date')
aal_df
# Out:
#       oc_change_by_volume
# date
# 0               -0.031624
# 1               -1.110815
# 2                2.044552
# 3                2.791781
# 4                8.331757
# ...                   ...
# 1254             0.229685
# 1255            -0.710699
# 1256             2.682746
# 1257             0.993285
# 1258             0.588290
#
# [1259 rows x 1 columns]

# %%
# num_samples = 100
# eps = 0.2

# X = np.array(range(0, len(aal_df), len(aal_df)//num_samples))
# y = aal_df.iloc[:num_samples].to_numpy()

X = np.array(range(len(aal_df)))
y = aal_df.to_numpy()

# plt.plot(X_, y_, 'r--')
plt.plot(X, y, 'bo')
plt.show()

# %%
# create simple feature map
param_x = Parameter('x')
feature_map = QuantumCircuit(1, name='fm')
feature_map.ry(param_x, 0)

# create simple ansatz
param_y = Parameter('y')
ansatz = QuantumCircuit(1, name='vf')
ansatz.ry(param_y, 0)

# create QNN
regression_opflow_qnn = TwoLayerQNN(1, feature_map, ansatz, quantum_instance=quantum_instance)

# %%
# create regressor from neural network
regressor = NeuralNetworkRegressor(neural_network=regression_opflow_qnn, loss='l2', optimizer=L_BFGS_B())

# %%
X = X.reshape(len(X),1)
X.shape
# Out:
# (1259, 1)

# %%
# fit to data
regressor.fit(X, y)

# score the result
regressor.score(X, y)
# Out:
# -0.08906240711661995

# %%
# plot data
plt.plot(X, y, 'bo')

# plot fitted line
y_ = regressor.predict(X)
plt.plot(X, y_, 'g-')
plt.show()

# %%
vqr = VQR(feature_map=feature_map,
          ansatz=ansatz,
          optimizer=L_BFGS_B(),
          quantum_instance=quantum_instance)

# %%
# fit regressor
vqr.fit(X, y)

# score result
vqr.score(X, y)
# Out:
# -0.09051307354708271

# %%
# plot target line
plt.plot(X[1200:], y[1200:], 'r--')

# plot data
plt.plot(X[1200:], y[1200:], 'bo')

# plot fitted line
y_ = vqr.predict(X)
plt.plot(X[1200:], y_[1200:], 'g-')
plt.show()

# %%
vqr.predict(1)
# Out:
# array([[-1.]])
